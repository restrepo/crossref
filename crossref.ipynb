# %% [markdown]
# # Crossref API

# %%
import pandas as pd

# %% [markdown]
# Resources
# * API TUTORIAL: https://github.com/CrossRef/rest-api-doc
# * JSON Format: https://github.com/Crossref/rest-api-doc/blob/master/api_format.md

# %% [markdown]
# ## Search by Journal

# %%
journal='kepes'
df=pd.read_json(
    'https://api.crossref.org/works?query.container-title={}&mailto=restrepo@udea.edu.co'.format(
    journal))

# %%
pd.DataFrame(
    df.loc['items']['message'])
# Out:
#                              DOI                    ISSN  \
# 0    10.17151/kepes.2015.12.11.1  [1794-7111, 2462-8115]
# 1      10.17151/kepes.2015.12.11  [1794-7111, 2462-8115]
# 2    10.17151/kepes.2015.12.11.2  [1794-7111, 2462-8115]
# 3    10.17151/kepes.2015.12.11.4  [1794-7111, 2462-8115]
# 4    10.17151/kepes.2015.12.11.5  [1794-7111, 2462-8115]
# 5    10.17151/kepes.2015.12.11.3  [1794-7111, 2462-8115]
# 6    10.17151/kepes.2015.12.11.7  [1794-7111, 2462-8115]
# 7    10.17151/kepes.2015.12.11.6  [1794-7111, 2462-8115]
# 8    10.17151/kepes.2015.12.11.8  [1794-7111, 2462-8115]
# 9    10.17151/kepes.2015.12.11.9  [1794-7111, 2462-8115]
# 10  10.17151/kepes.2015.12.11.11  [1794-7111, 2462-8115]
# 11  10.17151/kepes.2015.12.11.10  [1794-7111, 2462-8115]
# 12    10.17151/kepes.2015.12.12.  [1794-7111, 2462-8115]
# 13   10.17151/kepes.2015.12.12.1  [1794-7111, 2462-8115]
# 14   10.17151/kepes.2015.12.12.2  [1794-7111, 2462-8115]
# 15   10.17151/kepes.2015.12.12.3  [1794-7111, 2462-8115]
# 16   10.17151/kepes.2015.12.12.5  [1794-7111, 2462-8115]
# 17   10.17151/kepes.2015.12.12.6  [1794-7111, 2462-8115]
# 18   10.17151/kepes.2015.12.12.4  [1794-7111, 2462-8115]
# 19   10.17151/kepes.2015.12.12.7  [1794-7111, 2462-8115]
#
#                                                URL  \
# 0    http://dx.doi.org/10.17151/kepes.2015.12.11.1
# 1      http://dx.doi.org/10.17151/kepes.2015.12.11
# 2    http://dx.doi.org/10.17151/kepes.2015.12.11.2
# 3    http://dx.doi.org/10.17151/kepes.2015.12.11.4
# 4    http://dx.doi.org/10.17151/kepes.2015.12.11.5
# 5    http://dx.doi.org/10.17151/kepes.2015.12.11.3
# 6    http://dx.doi.org/10.17151/kepes.2015.12.11.7
# 7    http://dx.doi.org/10.17151/kepes.2015.12.11.6
# 8    http://dx.doi.org/10.17151/kepes.2015.12.11.8
# 9    http://dx.doi.org/10.17151/kepes.2015.12.11.9
# 10  http://dx.doi.org/10.17151/kepes.2015.12.11.11
# 11  http://dx.doi.org/10.17151/kepes.2015.12.11.10
# 12    http://dx.doi.org/10.17151/kepes.2015.12.12.
# 13   http://dx.doi.org/10.17151/kepes.2015.12.12.1
# 14   http://dx.doi.org/10.17151/kepes.2015.12.12.2
# 15   http://dx.doi.org/10.17151/kepes.2015.12.12.3
# 16   http://dx.doi.org/10.17151/kepes.2015.12.12.5
# 17   http://dx.doi.org/10.17151/kepes.2015.12.12.6
# 18   http://dx.doi.org/10.17151/kepes.2015.12.12.4
# 19   http://dx.doi.org/10.17151/kepes.2015.12.12.7
#
#                                                author container-title  \
# 0   [{'given': 'Gustavo A.', 'family': 'Villa Carm...         [Kepes]
# 1                                                 NaN         [Kepes]
# 2   [{'given': 'Walter', 'family': 'Castañeda M', ...         [Kepes]
# 3   [{'given': 'Yelicza', 'family': 'Marín Giraldo...         [Kepes]
# 4   [{'given': 'Maria João', 'family': 'Baltazar',...         [Kepes]
# 5   [{'given': 'Juan David', 'family': 'Chávez Gir...         [Kepes]
# 6   [{'given': 'Adriana', 'family': 'Gómez Alzate'...         [Kepes]
# 7   [{'given': 'Aurelio A.', 'family': 'Horta Mesa...         [Kepes]
# 8   [{'given': 'Camilo Fernando', 'family': 'Ruale...         [Kepes]
# 9   [{'given': 'Sandra Yaneth', 'family': 'Chaparr...         [Kepes]
# 10  [{'given': 'Oliver', 'family': 'Vodeb', 'seque...         [Kepes]
# 11  [{'given': 'Rossana', 'family': 'Bastías Casti...         [Kepes]
# 12                                                NaN         [kepes]
# 13  [{'ORCID': 'http://orcid.org/0000-0002-7037-91...         [kepes]
# 14  [{'given': 'Yolima', 'family': 'Sánchez Royo',...         [kepes]
# 15  [{'given': 'Óscar Julián', 'family': 'Cuesta M...         [kepes]
# 16  [{'given': 'Jairo Alfredo', 'family': 'Bermúde...         [kepes]
# 17  [{'given': 'Juan Sebastián', 'family': 'Ospina...         [kepes]
# 18  [{'given': 'Dimitri', 'family': 'Della Faille'...         [kepes]
# 19  [{'ORCID': 'http://orcid.org/0000-0002-1613-91...         [kepes]
#
#                                     content-domain  \
# 0   {'domain': [], 'crossmark-restriction': False}
# 1   {'domain': [], 'crossmark-restriction': False}
# 2   {'domain': [], 'crossmark-restriction': False}
# 3   {'domain': [], 'crossmark-restriction': False}
# 4   {'domain': [], 'crossmark-restriction': False}
# 5   {'domain': [], 'crossmark-restriction': False}
# 6   {'domain': [], 'crossmark-restriction': False}
# 7   {'domain': [], 'crossmark-restriction': False}
# 8   {'domain': [], 'crossmark-restriction': False}
# 9   {'domain': [], 'crossmark-restriction': False}
# 10  {'domain': [], 'crossmark-restriction': False}
# 11  {'domain': [], 'crossmark-restriction': False}
# 12  {'domain': [], 'crossmark-restriction': False}
# 13  {'domain': [], 'crossmark-restriction': False}
# 14  {'domain': [], 'crossmark-restriction': False}
# 15  {'domain': [], 'crossmark-restriction': False}
# 16  {'domain': [], 'crossmark-restriction': False}
# 17  {'domain': [], 'crossmark-restriction': False}
# 18  {'domain': [], 'crossmark-restriction': False}
# 19  {'domain': [], 'crossmark-restriction': False}
#
#                                               created  \
# 0   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 1   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 2   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 3   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 4   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 5   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 6   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 7   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 8   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 9   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 10  {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 11  {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 12  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 13  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 14  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 15  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 16  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 17  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 18  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 19  {'date-parts': [[2017, 10, 10]], 'date-time': ...
#
#                                             deposited  \
# 0   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 1   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 2   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 3   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 4   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 5   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 6   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 7   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 8   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 9   {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 10  {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 11  {'date-parts': [[2015, 8, 10]], 'date-time': '...
# 12  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 13  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 14  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 15  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 16  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 17  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 18  {'date-parts': [[2017, 10, 10]], 'date-time': ...
# 19  {'date-parts': [[2017, 10, 10]], 'date-time': ...
#
#                                               indexed  is-referenced-by-count  \
# 0   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       1
# 1   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 2   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 3   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 4   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 5   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 6   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 7   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 8   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 9   {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 10  {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 11  {'date-parts': [[2019, 11, 25]], 'date-time': ...                       0
# 12  {'date-parts': [[2019, 11, 27]], 'date-time': ...                       0
# 13  {'date-parts': [[2019, 11, 27]], 'date-time': ...                       0
# 14  {'date-parts': [[2019, 11, 27]], 'date-time': ...                       0
# 15  {'date-parts': [[2019, 11, 27]], 'date-time': ...                       0
# 16  {'date-parts': [[2019, 11, 27]], 'date-time': ...                       0
# 17  {'date-parts': [[2019, 11, 27]], 'date-time': ...                       0
# 18  {'date-parts': [[2019, 11, 27]], 'date-time': ...                       0
# 19  {'date-parts': [[2019, 11, 27]], 'date-time': ...                       0
#
#     ...                    published-print              publisher  \
# 0   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 1   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 2   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 3   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 4   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 5   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 6   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 7   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 8   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 9   ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 10  ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 11  ...     {'date-parts': [[2015, 6, 6]]}  Universidad de Caldas
# 12  ...    {'date-parts': [[2015, 12, 3]]}  Universidad de Caldas
# 13  ...    {'date-parts': [[2015, 12, 3]]}  Universidad de Caldas
# 14  ...    {'date-parts': [[2015, 12, 3]]}  Universidad de Caldas
# 15  ...    {'date-parts': [[2015, 12, 3]]}  Universidad de Caldas
# 16  ...    {'date-parts': [[2015, 12, 3]]}  Universidad de Caldas
# 17  ...    {'date-parts': [[2015, 12, 3]]}  Universidad de Caldas
# 18  ...    {'date-parts': [[2015, 12, 3]]}  Universidad de Caldas
# 19  ...    {'date-parts': [[2015, 12, 3]]}  Universidad de Caldas
#
#    reference-count references-count      score short-container-title  \
# 0                0                0  20.484732               [kepes]
# 1                0                0  20.484732               [kepes]
# 2                0                0  20.484732               [kepes]
# 3                0                0  20.484732               [kepes]
# 4                0                0  20.484732               [kepes]
# 5                0                0  20.484732               [kepes]
# 6                0                0  20.484732               [kepes]
# 7                0                0  20.484732               [kepes]
# 8                0                0  20.484732               [kepes]
# 9                0                0  20.484732               [kepes]
# 10               0                0  20.484732               [kepes]
# 11               0                0  20.484732               [kepes]
# 12               0                0  20.484732               [kepes]
# 13               0                0  20.484732               [kepes]
# 14               0                0  20.484732               [kepes]
# 15               0                0  20.484732               [kepes]
# 16               0                0  20.484732               [kepes]
# 17               0                0  20.484732               [kepes]
# 18               0                0  20.484732               [kepes]
# 19               0                0  20.484732               [kepes]
#
#       source                                              title  \
# 0   Crossref                                     [Presentación]
# 1   Crossref                                                NaN
# 2   Crossref  [Los memes y el diseño: contraste entre mensaj...
# 3   Crossref  [Metodología para la creación de micromundos i...
# 4   Crossref  [The Visual Archive: the self as author and ac...
# 5   Crossref  [La Casa Cielo: la connotación mágica del arqu...
# 6   Crossref  [Modelo de Diseño para la valoración y apropia...
# 7   Crossref      [Investigación: un nodo teorético del diseño]
# 8   Crossref  [Las emociones y la dación de sentido en los o...
# 9   Crossref  [Una mirada en blanco y negro: resignificación...
# 10  Crossref  [Debt, Marketing Communication, and The City: ...
# 11  Crossref  [La gestión del diseño en la empresa: el caso ...
# 12  Crossref                                                NaN
# 13  Crossref                                     [Presentación]
# 14  Crossref  [Patrones de color: Adaptación a nuevos método...
# 15  Crossref  [Criterios para pensar la planificación de la ...
# 16  Crossref  [El nacimiento del diseño gráfico en la educac...
# 17  Crossref  [El infierno de Flusser tiene pocos demonios y...
# 18  Crossref  [Reflexiones sobre los determinantes sociales ...
# 19  Crossref  [Diseño y Responsabilidad Social Empresarial e...
#
#                type volume
# 0   journal-article     12
# 1     journal-issue     12
# 2   journal-article     12
# 3   journal-article     12
# 4   journal-article     12
# 5   journal-article     12
# 6   journal-article     12
# 7   journal-article     12
# 8   journal-article     12
# 9   journal-article     12
# 10  journal-article     12
# 11  journal-article     12
# 12    journal-issue     12
# 13  journal-article     12
# 14  journal-article     12
# 15  journal-article     12
# 16  journal-article     12
# 17  journal-article     12
# 18  journal-article     12
# 19  journal-article     12
#
# [20 rows x 28 columns]
